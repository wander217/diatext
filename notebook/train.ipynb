# %%
# !git clone https://wander217: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@github.com/wander217/db_pp.git

# %%
# !pip install -r ./db_pp/requirements.txt

# %%
# !python './db_pp/det_trainer.py' -p './db_pp/config/dbpp_eb0.yaml' -i '../input/vintext/train/image' -t '../input/vintext/train/target.json' -it 1 -r '../input/checkpoint/checkpoint/last.pth'
